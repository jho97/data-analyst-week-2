# %% [markdown]
# # Coding Exercises

# %% [markdown]
# ## Full Data Workflow A-Z: Merging, Joining, Concatenating

# %% [markdown]
# ### Exercise 12: Merging, joining, aligning and concatenating Data

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Concatenating DataFrames vertically

# %% [markdown]
# __Import__ the cars dataset (with cars from usa and europe) from the csv-file __cars_clean.csv__. <br>
# Also __import__ the csv-file __cars_jap.csv__ (with cars from japan) and __concatenate__ both DataFrames __vertically__! <br>
# __Save__ the __concatenated DataFrame__ in the variable __cars_all__! <br>
# Finally, __sort__ cars_all by the model_year from __low to high__!

# %%
import pandas as pd

# %%
cars_data = pd.read_csv('cars_clean.csv')

# %%
cars_data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars_jp = pd.read_csv('cars_jap.csv')

# %%
cars_jp.head()
# Out:
#     mpg  cyl   disp    hp  weight   acc  year                   name
# 0  24.0    4  113.0  95.0    2372  15.0    70  toyota corona mark ii
# 1  27.0    4   97.0  88.0    2130  14.5    70           datsun pl510
# 2  27.0    4   97.0  88.0    2130  14.5    71           datsun pl510
# 3  25.0    4  113.0  95.0    2228  14.0    71          toyota corona
# 4  31.0    4   71.0  65.0    1773  19.0    71    toyota corolla 1200

# %%
pd.concat([cars_data, cars_jp], axis=0)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0        8.0         307.0       130.0    3504          12.0
# 1   15.0        8.0         350.0       165.0    3693          11.5
# 2   18.0        8.0         318.0       150.0    3436          11.0
# 3   16.0        8.0         304.0       150.0    3433          12.0
# 4   17.0        8.0         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 74  34.0        NaN           NaN         NaN    2245           NaN
# 75  38.0        NaN           NaN         NaN    1965           NaN
# 76  32.0        NaN           NaN         NaN    1965           NaN
# 77  38.0        NaN           NaN         NaN    1995           NaN
# 78  32.0        NaN           NaN         NaN    2665           NaN
#
#     model_year origin                       name  cyl   disp    hp   acc  year
# 0         70.0    usa  chevrolet chevelle malibu  NaN    NaN   NaN   NaN   NaN
# 1         70.0    usa          buick skylark 320  NaN    NaN   NaN   NaN   NaN
# 2         70.0    usa         plymouth satellite  NaN    NaN   NaN   NaN   NaN
# 3         70.0    usa              amc rebel sst  NaN    NaN   NaN   NaN   NaN
# 4         70.0    usa                ford torino  NaN    NaN   NaN   NaN   NaN
# ..         ...    ...                        ...  ...    ...   ...   ...   ...
# 74         NaN    NaN             toyota corolla  4.0  108.0  70.0  16.9  82.0
# 75         NaN    NaN                honda civic  4.0   91.0  67.0  15.0  82.0
# 76         NaN    NaN         honda civic (auto)  4.0   91.0  67.0  15.7  82.0
# 77         NaN    NaN              datsun 310 gx  4.0   91.0  67.0  16.2  82.0
# 78         NaN    NaN           toyota celica gt  4.0  144.0  96.0  13.9  82.0
#
# [392 rows x 14 columns]

# %%
cars_all = pd.concat([cars_data, cars_jp], axis=0)

# %%
cars_all.shape
# Out:
# (392, 14)

# %%
cars_all.sort_values(by='model_year', ascending=True)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0        8.0         307.0       130.0    3504          12.0
# 26   9.0        8.0         304.0       193.0    4732          18.5
# 25  11.0        8.0         318.0       210.0    4382          13.5
# 24  10.0        8.0         307.0       200.0    4376          15.0
# 23  10.0        8.0         360.0       215.0    4615          14.0
# ..   ...        ...           ...         ...     ...           ...
# 74  34.0        NaN           NaN         NaN    2245           NaN
# 75  38.0        NaN           NaN         NaN    1965           NaN
# 76  32.0        NaN           NaN         NaN    1965           NaN
# 77  38.0        NaN           NaN         NaN    1995           NaN
# 78  32.0        NaN           NaN         NaN    2665           NaN
#
#     model_year origin                       name  cyl   disp    hp   acc  year
# 0         70.0    usa  chevrolet chevelle malibu  NaN    NaN   NaN   NaN   NaN
# 26        70.0    usa                   ih 1200d  NaN    NaN   NaN   NaN   NaN
# 25        70.0    usa                 dodge d200  NaN    NaN   NaN   NaN   NaN
# 24        70.0    usa              chevrolet c20  NaN    NaN   NaN   NaN   NaN
# 23        70.0    usa                  ford f250  NaN    NaN   NaN   NaN   NaN
# ..         ...    ...                        ...  ...    ...   ...   ...   ...
# 74         NaN    NaN             toyota corolla  4.0  108.0  70.0  16.9  82.0
# 75         NaN    NaN                honda civic  4.0   91.0  67.0  15.0  82.0
# 76         NaN    NaN         honda civic (auto)  4.0   91.0  67.0  15.7  82.0
# 77         NaN    NaN              datsun 310 gx  4.0   91.0  67.0  16.2  82.0
# 78         NaN    NaN           toyota celica gt  4.0  144.0  96.0  13.9  82.0
#
# [392 rows x 14 columns]

# %%
cars_all["model_year"]
# Out:
# 0     70.0
# 1     70.0
# 2     70.0
# 3     70.0
# 4     70.0
#       ...
# 74     NaN
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# Name: model_year, Length: 392, dtype: float64

# %% [markdown]
# ### need to align before concat

# %%
cars_jp.insert(7, "origin", "japan")
# insert(loc, column, value, allow_duplicates = False)

# %%
cars_jp.columns = cars_data.columns
#overwriting the columns

# %%
cars_jp.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  24.0          4         113.0        95.0    2372          15.0
# 1  27.0          4          97.0        88.0    2130          14.5
# 2  27.0          4          97.0        88.0    2130          14.5
# 3  25.0          4         113.0        95.0    2228          14.0
# 4  31.0          4          71.0        65.0    1773          19.0
#
#    model_year origin                   name
# 0          70  japan  toyota corona mark ii
# 1          70  japan           datsun pl510
# 2          71  japan           datsun pl510
# 3          71  japan          toyota corona
# 4          71  japan    toyota corolla 1200

# %%
cars_all2 = pd.concat([cars_data, cars_jp], ignore_index=True)

# %%
cars_all2.head()
cars_all2.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 387  34.0          4         108.0        70.0    2245          16.9
# 388  38.0          4          91.0        67.0    1965          15.0
# 389  32.0          4          91.0        67.0    1965          15.7
# 390  38.0          4          91.0        67.0    1995          16.2
# 391  32.0          4         144.0        96.0    2665          13.9
#
#      model_year origin                name
# 387          82  japan      toyota corolla
# 388          82  japan         honda civic
# 389          82  japan  honda civic (auto)
# 390          82  japan       datsun 310 gx
# 391          82  japan    toyota celica gt

# %%
cars_all2 = cars_all2.sort_values("model_year").reset_index(drop=True)

# %%
cars_all2.head()
cars_all2.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 387  44.0          4          97.0        52.0    2130          24.6
# 388  32.0          4         135.0        84.0    2295          11.6
# 389  28.0          4         120.0        79.0    2625          18.6
# 390  38.0          4          91.0        67.0    1995          16.2
# 391  32.0          4         144.0        96.0    2665          13.9
#
#      model_year  origin              name
# 387          82  europe         vw pickup
# 388          82     usa     dodge rampage
# 389          82     usa       ford ranger
# 390          82   japan     datsun 310 gx
# 391          82   japan  toyota celica gt

# %%
cars_all2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 27.7+ KB

# %% [markdown]
# ### Left Join

# %% [markdown]
# __Import__ the csv-files __summer.csv__ (as summer) and __dictionary.csv__ (as dic) which contains the __full country name__ for the olympic country codes as well as __population__ and __gdp__ statistics for some countries.<br>
#
# __"Copy and paste"__ the __full country name__, __population__ and __gdp__ from the dic DataFrame __into the summer DataFrame__ with a __Left Join__!<br>
# __Save__ the new merged DataFrame in the variable __summer_new__!<br>
#
# __Inspect__ summer_new and determine the __olympic country codes__ for which the dic DataFrame does __not provide__ any information!

# %%
summer = pd.read_csv('summer.csv')
dic = pd.read_csv('dictionary.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
dic.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
pd.merge(summer, dic, how='left')
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal Code  Population  GDP per Capita
# 0        Gold  NaN         NaN             NaN
# 1      Silver  NaN         NaN             NaN
# 2      Bronze  NaN         NaN             NaN
# 3        Gold  NaN         NaN             NaN
# 4      Silver  NaN         NaN             NaN
# ...       ...  ...         ...             ...
# 31160  Bronze  NaN         NaN             NaN
# 31161    Gold  NaN         NaN             NaN
# 31162  Silver  NaN         NaN             NaN
# 31163  Bronze  NaN         NaN             NaN
# 31164  Bronze  NaN         NaN             NaN
#
# [31165 rows x 12 columns]

# %%
pd.merge(summer, dic, how='left', left_on="Country", right_on='Code')
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country_x Gender                       Event  \
# 0                  HAJOS, Alfred       HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto       AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios       GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis       GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon       GRE    Men  100M Freestyle For Sailors
# ...                          ...       ...    ...                         ...
# 31160         JANIKOWSKI, Damian       POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza       IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam       RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur       ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy       SWE    Men                    Wg 96 KG
#
#         Medal Country_y Code   Population  GDP per Capita
# 0        Gold   Hungary  HUN    9844686.0    12363.543460
# 1      Silver   Austria  AUT    8611088.0    43774.985174
# 2      Bronze    Greece  GRE   10823732.0    18002.230578
# 3        Gold    Greece  GRE   10823732.0    18002.230578
# 4      Silver    Greece  GRE   10823732.0    18002.230578
# ...       ...       ...  ...          ...             ...
# 31160  Bronze    Poland  POL   37999494.0    12554.547554
# 31161    Gold      Iran  IRI   79109272.0             NaN
# 31162  Silver    Russia  RUS  144096812.0     9092.580536
# 31163  Bronze   Armenia  ARM    3017712.0     3489.127690
# 31164  Bronze    Sweden  SWE    9798871.0    50579.673649
#
# [31165 rows x 13 columns]

# %%
summer_new = pd.merge(summer, dic, how='left', left_on="Country", right_on='Code')

# %%
summer_new.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country_x Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred       HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto       AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios       GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis       GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon       GRE    Men
#
#                         Event   Medal Country_y Code  Population  \
# 0              100M Freestyle    Gold   Hungary  HUN   9844686.0
# 1              100M Freestyle  Silver   Austria  AUT   8611088.0
# 2  100M Freestyle For Sailors  Bronze    Greece  GRE  10823732.0
# 3  100M Freestyle For Sailors    Gold    Greece  GRE  10823732.0
# 4  100M Freestyle For Sailors  Silver    Greece  GRE  10823732.0
#
#    GDP per Capita
# 0    12363.543460
# 1    43774.985174
# 2    18002.230578
# 3    18002.230578
# 4    18002.230578

# %% [markdown]
# ### Arithmetic operations between DataFrames / Alignment

# %% [markdown]
# __Import__ the csv-files __ath_2008.csv__ and __ath_2012.csv__ with all medals winners in the Sport __Athletics__ in the Editions __2008__ and __2012__.

# %%
ath_08 = pd.read_csv('ath_2008.csv')
ath_12 = pd.read_csv('ath_2012.csv')

# %%
import numpy as np

# %%
ath_08.head()
# Out:
#               Athlete  Gold  Silver  Bronze
# 0    ABAKUMOVA, Maria     0       1       0
# 1  ABEYLEGESSE, Elvan     0       2       0
# 2  ALEKNA, Virgilijus     0       0       1
# 3      ALEXEEV, Denis     0       0       1
# 4     ANTONOVA, Olena     0       0       1

# %%
ath_12.head()
# Out:
#               Athlete  Gold  Silver  Bronze
# 0      ADAMS, Valerie     1       0       0
# 1  ALLEYNE-FORTE, Ade     0       0       1
# 2         AMOS, Nijel     0       1       0
# 3    ANTYUKH, Natalya     1       1       0
# 4       ASSEFA, Sofia     0       1       0

# %%
ath_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Athlete  159 non-null    object
#  1   Gold     159 non-null    int64
#  2   Silver   159 non-null    int64
#  3   Bronze   159 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.1+ KB

# %%
ath_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Athlete  171 non-null    object
#  1   Gold     171 non-null    int64
#  2   Silver   171 non-null    int64
#  3   Bronze   171 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.5+ KB

# %%
pd.merge(ath_08, ath_12, how="left", left_on="Athlete", right_on="Gold")
#can't be done because of invalid key types
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7l/pflnpn3514n8ldfcmnrpr5q00000gn/T/ipykernel_5105/419440465.py in <module>
# ----> 1 pd.merge(ath_08, ath_12, how="left", left_on="Athlete", right_on="Gold")
#
# ~/opt/anaconda3/envs/VirtEnv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~/opt/anaconda3/envs/VirtEnv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     701         # validate the merge keys dtypes. We may need to coerce
#     702         # to avoid incompatible dtypes
# --> 703         self._maybe_coerce_merge_keys()
#     704
#     705         # If argument passed to validate,
#
# ~/opt/anaconda3/envs/VirtEnv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1254                     inferred_right in string_types and inferred_left not in string_types
#    1255                 ):
# -> 1256                     raise ValueError(msg)
#    1257
#    1258             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
ath_08.set_index("Athlete", inplace=True)
ath_12.set_index("Athlete", inplace=True)

# %% [markdown]
# For __all Athletes__ in the two DataFrames, __aggregate/add__ the total number of __Gold__, __Silver__ and __Bronze__ Medals over both editions! __Save__ the aggregated DataFrame in the variable __add__. (Hint: add should contain an index with the Athlete names and three columns, Gold, Silver, Bronze)

# %% [markdown]
# __Sort__ add by Gold, Silver, Bronze from __high to low__! Change datatype to __integer__, if necessary! The first Athlete in your DataFrame should be ... no surprise ... Usain Bolt with 6 Gold and 0 Silver and Bronze Medals.

# %% [markdown]
# -------------------------------------
